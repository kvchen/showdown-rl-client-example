# %% [markdown]
# # Pokemon Showdown RL Client Example

# %%
import requests

# %%
HOST = "http://localhost"
PORT = 3000

BASE_URL = f"{HOST}:{PORT}/game"

# %%
def create_battle():
    url = f"{BASE_URL}/new"
    return requests.post(url).json()

def do_move(battle_id, move_type, message):
    url = f"{BASE_URL}/{battle_id}/move"
    return requests.post(url, data={"moveType": move_type, "message": message}).json()

def cleanup(battle_id):
    url = f"{BASE_URL}/{battle_id}"
    return requests.delete(url)

# %%
def print_log(log):
    print('\n'.join(log))

# %%
game = create_battle()
battle_id, battle = game["battleID"], game["battle"]

print(battle_id)
print_log(battle["inputLog"])

print(battle["sides"][0]["pokemon"])
# Out:
# 08853c82-5f19-43b6-aa6a-e5e93e562154
# >start {"seed":[30390,14716,9550,25973]}
# >player p1 {}
# >player p2 {}
# [{'hp': 257, 'health': '48/48', 'details': 'Crobat, L77, F|48/48'}, {'hp': 227, 'health': '48/48', 'details': 'Pyukumuku, L83, F|48/48'}, {'hp': 235, 'health': '48/48', 'details': 'Raichu, L83, F|48/48'}, {'hp': 260, 'health': '48/48', 'details': 'Bellossom, L83, M|48/48'}, {'hp': 169, 'health': '48/48', 'details': 'Shuckle, L83, M|48/48'}, {'hp': 244, 'health': '48/48', 'details': 'Infernape, L77, M|48/48'}]

# %%
ended, counter = False, 0

while not ended:
    next_battle = do_move(battle_id, "p1" if counter % 2 == 0 else "p2", "default")
    battle_id = next_battle["battleID"]
    ended = next_battle["battle"]["ended"]
    counter += 1

print_log(next_battle["battle"]["log"])
# Out:
# |player|p1|Player 1|
# |player|p2|Player 2|
# |teamsize|p1|6
# |teamsize|p2|6
# |gametype|singles
# |gen|7
# |tier|
# |split
# |seed|
# |seed|
# |seed|
# |seed|30390,14716,9550,25973
# |
# |start
# |split
# |switch|p1a: Crobat|Crobat, L77, F|48/48
# |switch|p1a: Crobat|Crobat, L77, F|257/257
# |switch|p1a: Crobat|Crobat, L77, F|48/48
# |switch|p1a: Crobat|Crobat, L77, F|257/257
# |split
# |switch|p2a: Arbok|Arbok, L83, M|48/48
# |switch|p2a: Arbok|Arbok, L83, M|48/48
# |switch|p2a: Arbok|Arbok, L83, M|235/235
# |switch|p2a: Arbok|Arbok, L83, M|235/235
# |turn|1
# |
# |move|p1a: Crobat|Roost||[still]
# |-fail|p1a: Crobat
# |move|p2a: Arbok|Coil|p2a: Arbok
# |-boost|p2a: Arbok|atk|1
# |-boost|p2a: Arbok|def|1
# |-boost|p2a: Arbok|accuracy|1
# |
# |upkeep
# |turn|2
# |
# |move|p1a: Crobat|Roost||[still]
# |-fail|p1a: Crobat
# |move|p2a: Arbok|Coil|p2a: Arbok
# |-boost|p2a: Arbok|atk|1
# |-boost|p2a: Arbok|def|1
# |-boost|p2a: Arbok|accuracy|1
# |
# |upkeep
# |turn|3
# |
# |move|p1a: Crobat|Roost||[still]
# |-fail|p1a: Crobat
# |move|p2a: Arbok|Coil|p2a: Arbok
# |-boost|p2a: Arbok|atk|1
# |-boost|p2a: Arbok|def|1
# |-boost|p2a: Arbok|accuracy|1
# |
# |upkeep
# |turn|4
# |
# |move|p1a: Crobat|Roost||[still]
# |-fail|p1a: Crobat
# |move|p2a: Arbok|Coil|p2a: Arbok
# |-boost|p2a: Arbok|atk|1
# |-boost|p2a: Arbok|def|1
# |-boost|p2a: Arbok|accuracy|1
# |
# |upkeep
# |turn|5
# |
# |move|p1a: Crobat|Roost||[still]
# |-fail|p1a: Crobat
# |move|p2a: Arbok|Coil|p2a: Arbok
# |-boost|p2a: Arbok|atk|1
# |-boost|p2a: Arbok|def|1
# |-boost|p2a: Arbok|accuracy|1
# |
# |upkeep
# |turn|6
# |
# |move|p1a: Crobat|Roost||[still]
# |-fail|p1a: Crobat
# |move|p2a: Arbok|Coil|p2a: Arbok
# |-boost|p2a: Arbok|atk|1
# |-boost|p2a: Arbok|def|1
# |-boost|p2a: Arbok|accuracy|1
# |
# |upkeep
# |turn|7
# |
# |move|p1a: Crobat|Roost||[still]
# |-fail|p1a: Crobat
# |move|p2a: Arbok|Coil|p2a: Arbok
# |-boost|p2a: Arbok|atk|0
# |-boost|p2a: Arbok|def|0
# |-boost|p2a: Arbok|accuracy|0
# |
# |upkeep
# |turn|8
# |
# |move|p1a: Crobat|Roost||[still]
# |-fail|p1a: Crobat
# |move|p2a: Arbok|Coil|p2a: Arbok
# |-boost|p2a: Arbok|atk|0
# |-boost|p2a: Arbok|def|0
# |-boost|p2a: Arbok|accuracy|0
# |
# |upkeep
# |turn|9
# |
# |move|p1a: Crobat|Roost||[still]
# |-fail|p1a: Crobat
# |move|p2a: Arbok|Coil|p2a: Arbok
# |-boost|p2a: Arbok|atk|0
# |-boost|p2a: Arbok|def|0
# |-boost|p2a: Arbok|accuracy|0
# |
# |upkeep
# |turn|10
# |
# |move|p1a: Crobat|Roost||[still]
# |-fail|p1a: Crobat
# |move|p2a: Arbok|Coil|p2a: Arbok
# |-boost|p2a: Arbok|atk|0
# |-boost|p2a: Arbok|def|0
# |-boost|p2a: Arbok|accuracy|0
# |
# |upkeep
# |turn|11
# |
# |move|p1a: Crobat|Roost||[still]
# |-fail|p1a: Crobat
# |move|p2a: Arbok|Coil|p2a: Arbok
# |-boost|p2a: Arbok|atk|0
# |-boost|p2a: Arbok|def|0
# |-boost|p2a: Arbok|accuracy|0
# |
# |upkeep
# |turn|12
# |
# |move|p1a: Crobat|Roost||[still]
# |-fail|p1a: Crobat
# |move|p2a: Arbok|Coil|p2a: Arbok
# |-boost|p2a: Arbok|atk|0
# |-boost|p2a: Arbok|def|0
# |-boost|p2a: Arbok|accuracy|0
# |
# |upkeep
# |turn|13
# |
# |move|p1a: Crobat|Roost||[still]
# |-fail|p1a: Crobat
# |move|p2a: Arbok|Coil|p2a: Arbok
# |-boost|p2a: Arbok|atk|0
# |-boost|p2a: Arbok|def|0
# |-boost|p2a: Arbok|accuracy|0
# |
# |upkeep
# |turn|14
# |
# |move|p1a: Crobat|Roost||[still]
# |-fail|p1a: Crobat
# |move|p2a: Arbok|Coil|p2a: Arbok
# |-boost|p2a: Arbok|atk|0
# |-boost|p2a: Arbok|def|0
# |-boost|p2a: Arbok|accuracy|0
# |
# |upkeep
# |turn|15
# |
# |move|p1a: Crobat|Roost||[still]
# |-fail|p1a: Crobat
# |move|p2a: Arbok|Coil|p2a: Arbok
# |-boost|p2a: Arbok|atk|0
# |-boost|p2a: Arbok|def|0
# |-boost|p2a: Arbok|accuracy|0
# |
# |upkeep
# |turn|16
# |
# |move|p1a: Crobat|Roost||[still]
# |-fail|p1a: Crobat
# |move|p2a: Arbok|Coil|p2a: Arbok
# |-boost|p2a: Arbok|atk|0
# |-boost|p2a: Arbok|def|0
# |-boost|p2a: Arbok|accuracy|0
# |
# |upkeep
# |turn|17
# |
# |move|p1a: Crobat|Toxic|p2a: Arbok
# |-immune|p2a: Arbok|[msg]
# |move|p2a: Arbok|Coil|p2a: Arbok
# |-boost|p2a: Arbok|atk|0
# |-boost|p2a: Arbok|def|0
# |-boost|p2a: Arbok|accuracy|0
# |
# |upkeep
# |turn|18
# |
# |move|p1a: Crobat|Toxic|p2a: Arbok
# |-immune|p2a: Arbok|[msg]
# |move|p2a: Arbok|Coil|p2a: Arbok
# |-boost|p2a: Arbok|atk|0
# |-boost|p2a: Arbok|def|0
# |-boost|p2a: Arbok|accuracy|0
# |
# |upkeep
# |turn|19
# |
# |move|p1a: Crobat|Toxic|p2a: Arbok
# |-immune|p2a: Arbok|[msg]
# |move|p2a: Arbok|Coil|p2a: Arbok
# |-boost|p2a: Arbok|atk|0
# |-boost|p2a: Arbok|def|0
# |-boost|p2a: Arbok|accuracy|0
# |
# |upkeep
# |turn|20
# |
# |move|p1a: Crobat|Toxic|p2a: Arbok
# |-immune|p2a: Arbok|[msg]
# |move|p2a: Arbok|Coil|p2a: Arbok
# |-boost|p2a: Arbok|atk|0
# |-boost|p2a: Arbok|def|0
# |-boost|p2a: Arbok|accuracy|0
# |
# |upkeep
# |turn|21
# |
# |move|p1a: Crobat|Toxic|p2a: Arbok
# |-immune|p2a: Arbok|[msg]
# |move|p2a: Arbok|Coil|p2a: Arbok
# |-boost|p2a: Arbok|atk|0
# |-boost|p2a: Arbok|def|0
# |-boost|p2a: Arbok|accuracy|0
# |
# |upkeep
# |turn|22
# |
# |move|p1a: Crobat|Toxic|p2a: Arbok
# |-immune|p2a: Arbok|[msg]
# |move|p2a: Arbok|Coil|p2a: Arbok
# |-boost|p2a: Arbok|atk|0
# |-boost|p2a: Arbok|def|0
# |-boost|p2a: Arbok|accuracy|0
# |
# |upkeep
# |turn|23
# |
# |move|p1a: Crobat|Toxic|p2a: Arbok
# |-immune|p2a: Arbok|[msg]
# |move|p2a: Arbok|Coil|p2a: Arbok
# |-boost|p2a: Arbok|atk|0
# |-boost|p2a: Arbok|def|0
# |-boost|p2a: Arbok|accuracy|0
# |
# |upkeep
# |turn|24
# |
# |move|p1a: Crobat|Toxic|p2a: Arbok
# |-immune|p2a: Arbok|[msg]
# |move|p2a: Arbok|Coil|p2a: Arbok
# |-boost|p2a: Arbok|atk|0
# |-boost|p2a: Arbok|def|0
# |-boost|p2a: Arbok|accuracy|0
# |
# |upkeep
# |turn|25
# |
# |move|p1a: Crobat|Toxic|p2a: Arbok
# |-immune|p2a: Arbok|[msg]
# |move|p2a: Arbok|Coil|p2a: Arbok
# |-boost|p2a: Arbok|atk|0
# |-boost|p2a: Arbok|def|0
# |-boost|p2a: Arbok|accuracy|0
# |
# |upkeep
# |turn|26
# |
# |move|p1a: Crobat|Toxic|p2a: Arbok
# |-immune|p2a: Arbok|[msg]
# |move|p2a: Arbok|Coil|p2a: Arbok
# |-boost|p2a: Arbok|atk|0
# |-boost|p2a: Arbok|def|0
# |-boost|p2a: Arbok|accuracy|0
# |
# |upkeep
# |turn|27
# |
# |move|p1a: Crobat|Toxic|p2a: Arbok
# |-immune|p2a: Arbok|[msg]
# |move|p2a: Arbok|Coil|p2a: Arbok
# |-boost|p2a: Arbok|atk|0
# |-boost|p2a: Arbok|def|0
# |-boost|p2a: Arbok|accuracy|0
# |
# |upkeep
# |turn|28
# |
# |move|p1a: Crobat|Toxic|p2a: Arbok
# |-immune|p2a: Arbok|[msg]
# |move|p2a: Arbok|Coil|p2a: Arbok
# |-boost|p2a: Arbok|atk|0
# |-boost|p2a: Arbok|def|0
# |-boost|p2a: Arbok|accuracy|0
# |
# |upkeep
# |turn|29
# |
# |move|p1a: Crobat|Toxic|p2a: Arbok
# |-immune|p2a: Arbok|[msg]
# |move|p2a: Arbok|Coil|p2a: Arbok
# |-boost|p2a: Arbok|atk|0
# |-boost|p2a: Arbok|def|0
# |-boost|p2a: Arbok|accuracy|0
# |
# |upkeep
# |turn|30
# |
# |move|p1a: Crobat|Toxic|p2a: Arbok
# |-immune|p2a: Arbok|[msg]
# |move|p2a: Arbok|Coil|p2a: Arbok
# |-boost|p2a: Arbok|atk|0
# |-boost|p2a: Arbok|def|0
# |-boost|p2a: Arbok|accuracy|0
# |
# |upkeep
# |turn|31
# |
# |move|p1a: Crobat|Toxic|p2a: Arbok
# |-immune|p2a: Arbok|[msg]
# |move|p2a: Arbok|Coil|p2a: Arbok
# |-boost|p2a: Arbok|atk|0
# |-boost|p2a: Arbok|def|0
# |-boost|p2a: Arbok|accuracy|0
# |
# |upkeep
# |turn|32
# |
# |move|p1a: Crobat|Toxic|p2a: Arbok
# |-immune|p2a: Arbok|[msg]
# |move|p2a: Arbok|Coil|p2a: Arbok
# |-boost|p2a: Arbok|atk|0
# |-boost|p2a: Arbok|def|0
# |-boost|p2a: Arbok|accuracy|0
# |
# |upkeep
# |turn|33
# |
# |move|p1a: Crobat|Brave Bird|p2a: Arbok
# |split
# |-damage|p2a: Arbok|41/48
# |-damage|p2a: Arbok|41/48
# |-damage|p2a: Arbok|205/235
# |-damage|p2a: Arbok|205/235
# |split
# |-damage|p1a: Crobat|46/48|[from] Recoil
# |-damage|p1a: Crobat|247/257|[from] Recoil
# |-damage|p1a: Crobat|46/48|[from] Recoil
# |-damage|p1a: Crobat|247/257|[from] Recoil
# |move|p2a: Arbok|Rest|p2a: Arbok
# |-status|p2a: Arbok|slp
# |split
# |-heal|p2a: Arbok|48/48 slp|[silent]
# |-heal|p2a: Arbok|48/48 slp|[silent]
# |-heal|p2a: Arbok|235/235 slp|[silent]
# |-heal|p2a: Arbok|235/235 slp|[silent]
# |-status|p2a: Arbok|slp|[from] move: Rest
# |
# |split
# |-heal|p1a: Crobat|48/48|[from] item: Black Sludge
# |-heal|p1a: Crobat|257/257|[from] item: Black Sludge
# |-heal|p1a: Crobat|48/48|[from] item: Black Sludge
# |-heal|p1a: Crobat|257/257|[from] item: Black Sludge
# |upkeep
# |turn|34
# |
# |move|p1a: Crobat|Brave Bird|p2a: Arbok
# |split
# |-damage|p2a: Arbok|42/48 slp
# |-damage|p2a: Arbok|42/48 slp
# |-damage|p2a: Arbok|207/235 slp
# |-damage|p2a: Arbok|207/235 slp
# |split
# |-damage|p1a: Crobat|46/48|[from] Recoil
# |-damage|p1a: Crobat|248/257|[from] Recoil
# |-damage|p1a: Crobat|46/48|[from] Recoil
# |-damage|p1a: Crobat|248/257|[from] Recoil
# |cant|p2a: Arbok|slp
# |
# |split
# |-heal|p1a: Crobat|48/48|[from] item: Black Sludge
# |-heal|p1a: Crobat|257/257|[from] item: Black Sludge
# |-heal|p1a: Crobat|48/48|[from] item: Black Sludge
# |-heal|p1a: Crobat|257/257|[from] item: Black Sludge
# |upkeep
# |turn|35
# |
# |move|p1a: Crobat|Brave Bird|p2a: Arbok
# |split
# |-damage|p2a: Arbok|35/48 slp
# |-damage|p2a: Arbok|35/48 slp
# |-damage|p2a: Arbok|176/235 slp
# |-damage|p2a: Arbok|176/235 slp
# |split
# |-damage|p1a: Crobat|46/48|[from] Recoil
# |-damage|p1a: Crobat|247/257|[from] Recoil
# |-damage|p1a: Crobat|46/48|[from] Recoil
# |-damage|p1a: Crobat|247/257|[from] Recoil
# |cant|p2a: Arbok|slp
# |
# |split
# |-heal|p1a: Crobat|48/48|[from] item: Black Sludge
# |-heal|p1a: Crobat|257/257|[from] item: Black Sludge
# |-heal|p1a: Crobat|48/48|[from] item: Black Sludge
# |-heal|p1a: Crobat|257/257|[from] item: Black Sludge
# |-activate|p2a: Arbok|ability: Shed Skin
# |-curestatus|p2a: Arbok|slp|[msg]
# |upkeep
# |turn|36
# |
# |move|p1a: Crobat|Brave Bird|p2a: Arbok
# |split
# |-damage|p2a: Arbok|29/48
# |-damage|p2a: Arbok|29/48
# |-damage|p2a: Arbok|146/235
# |-damage|p2a: Arbok|146/235
# |split
# |-damage|p1a: Crobat|46/48|[from] Recoil
# |-damage|p1a: Crobat|247/257|[from] Recoil
# |-damage|p1a: Crobat|46/48|[from] Recoil
# |-damage|p1a: Crobat|247/257|[from] Recoil
# |move|p2a: Arbok|Rest|p2a: Arbok
# |-status|p2a: Arbok|slp
# |split
# |-heal|p2a: Arbok|48/48 slp|[silent]
# |-heal|p2a: Arbok|48/48 slp|[silent]
# |-heal|p2a: Arbok|235/235 slp|[silent]
# |-heal|p2a: Arbok|235/235 slp|[silent]
# |-status|p2a: Arbok|slp|[from] move: Rest
# |
# |split
# |-heal|p1a: Crobat|48/48|[from] item: Black Sludge
# |-heal|p1a: Crobat|257/257|[from] item: Black Sludge
# |-heal|p1a: Crobat|48/48|[from] item: Black Sludge
# |-heal|p1a: Crobat|257/257|[from] item: Black Sludge
# |upkeep
# |turn|37
# |
# |move|p1a: Crobat|Brave Bird|p2a: Arbok
# |split
# |-damage|p2a: Arbok|41/48 slp
# |-damage|p2a: Arbok|41/48 slp
# |-damage|p2a: Arbok|204/235 slp
# |-damage|p2a: Arbok|204/235 slp
# |split
# |-damage|p1a: Crobat|46/48|[from] Recoil
# |-damage|p1a: Crobat|247/257|[from] Recoil
# |-damage|p1a: Crobat|46/48|[from] Recoil
# |-damage|p1a: Crobat|247/257|[from] Recoil
# |cant|p2a: Arbok|slp
# |
# |split
# |-heal|p1a: Crobat|48/48|[from] item: Black Sludge
# |-heal|p1a: Crobat|257/257|[from] item: Black Sludge
# |-heal|p1a: Crobat|48/48|[from] item: Black Sludge
# |-heal|p1a: Crobat|257/257|[from] item: Black Sludge
# |-activate|p2a: Arbok|ability: Shed Skin
# |-curestatus|p2a: Arbok|slp|[msg]
# |upkeep
# |turn|38
# |
# |move|p1a: Crobat|Brave Bird|p2a: Arbok
# |split
# |-damage|p2a: Arbok|35/48
# |-damage|p2a: Arbok|35/48
# |-damage|p2a: Arbok|173/235
# |-damage|p2a: Arbok|173/235
# |split
# |-damage|p1a: Crobat|46/48|[from] Recoil
# |-damage|p1a: Crobat|247/257|[from] Recoil
# |-damage|p1a: Crobat|46/48|[from] Recoil
# |-damage|p1a: Crobat|247/257|[from] Recoil
# |move|p2a: Arbok|Rest|p2a: Arbok
# |-status|p2a: Arbok|slp
# |split
# |-heal|p2a: Arbok|48/48 slp|[silent]
# |-heal|p2a: Arbok|48/48 slp|[silent]
# |-heal|p2a: Arbok|235/235 slp|[silent]
# |-heal|p2a: Arbok|235/235 slp|[silent]
# |-status|p2a: Arbok|slp|[from] move: Rest
# |
# |split
# |-heal|p1a: Crobat|48/48|[from] item: Black Sludge
# |-heal|p1a: Crobat|257/257|[from] item: Black Sludge
# |-heal|p1a: Crobat|48/48|[from] item: Black Sludge
# |-heal|p1a: Crobat|257/257|[from] item: Black Sludge
# |-activate|p2a: Arbok|ability: Shed Skin
# |-curestatus|p2a: Arbok|slp|[msg]
# |upkeep
# |turn|39
# |
# |move|p1a: Crobat|Brave Bird|p2a: Arbok
# |split
# |-damage|p2a: Arbok|41/48
# |-damage|p2a: Arbok|41/48
# |-damage|p2a: Arbok|204/235
# |-damage|p2a: Arbok|204/235
# |split
# |-damage|p1a: Crobat|46/48|[from] Recoil
# |-damage|p1a: Crobat|247/257|[from] Recoil
# |-damage|p1a: Crobat|46/48|[from] Recoil
# |-damage|p1a: Crobat|247/257|[from] Recoil
# |move|p2a: Arbok|Rest|p2a: Arbok
# |-status|p2a: Arbok|slp
# |split
# |-heal|p2a: Arbok|48/48 slp|[silent]
# |-heal|p2a: Arbok|48/48 slp|[silent]
# |-heal|p2a: Arbok|235/235 slp|[silent]
# |-heal|p2a: Arbok|235/235 slp|[silent]
# |-status|p2a: Arbok|slp|[from] move: Rest
# |
# |split
# |-heal|p1a: Crobat|48/48|[from] item: Black Sludge
# |-heal|p1a: Crobat|257/257|[from] item: Black Sludge
# |-heal|p1a: Crobat|48/48|[from] item: Black Sludge
# |-heal|p1a: Crobat|257/257|[from] item: Black Sludge
# |upkeep
# |turn|40
# |
# |move|p1a: Crobat|Brave Bird|p2a: Arbok
# |split
# |-damage|p2a: Arbok|41/48 slp
# |-damage|p2a: Arbok|41/48 slp
# |-damage|p2a: Arbok|202/235 slp
# |-damage|p2a: Arbok|202/235 slp
# |split
# |-damage|p1a: Crobat|45/48|[from] Recoil
# |-damage|p1a: Crobat|246/257|[from] Recoil
# |-damage|p1a: Crobat|45/48|[from] Recoil
# |-damage|p1a: Crobat|246/257|[from] Recoil
# |cant|p2a: Arbok|slp
# |
# |split
# |-heal|p1a: Crobat|48/48|[from] item: Black Sludge
# |-heal|p1a: Crobat|257/257|[from] item: Black Sludge
# |-heal|p1a: Crobat|48/48|[from] item: Black Sludge
# |-heal|p1a: Crobat|257/257|[from] item: Black Sludge
# |upkeep
# |turn|41
# |
# |move|p1a: Crobat|Brave Bird|p2a: Arbok
# |split
# |-damage|p2a: Arbok|34/48 slp
# |-damage|p2a: Arbok|34/48 slp
# |-damage|p2a: Arbok|171/235 slp
# |-damage|p2a: Arbok|171/235 slp
# |split
# |-damage|p1a: Crobat|46/48|[from] Recoil
# |-damage|p1a: Crobat|247/257|[from] Recoil
# |-damage|p1a: Crobat|46/48|[from] Recoil
# |-damage|p1a: Crobat|247/257|[from] Recoil
# |cant|p2a: Arbok|slp
# |
# |split
# |-heal|p1a: Crobat|48/48|[from] item: Black Sludge
# |-heal|p1a: Crobat|257/257|[from] item: Black Sludge
# |-heal|p1a: Crobat|48/48|[from] item: Black Sludge
# |-heal|p1a: Crobat|257/257|[from] item: Black Sludge
# |upkeep
# |turn|42
# |
# |move|p1a: Crobat|Brave Bird|p2a: Arbok
# |split
# |-damage|p2a: Arbok|28/48 slp
# |-damage|p2a: Arbok|28/48 slp
# |-damage|p2a: Arbok|138/235 slp
# |-damage|p2a: Arbok|138/235 slp
# |split
# |-damage|p1a: Crobat|45/48|[from] Recoil
# |-damage|p1a: Crobat|246/257|[from] Recoil
# |-damage|p1a: Crobat|45/48|[from] Recoil
# |-damage|p1a: Crobat|246/257|[from] Recoil
# |-curestatus|p2a: Arbok|slp|[msg]
# |move|p2a: Arbok|Rest|p2a: Arbok
# |-status|p2a: Arbok|slp
# |split
# |-heal|p2a: Arbok|48/48 slp|[silent]
# |-heal|p2a: Arbok|48/48 slp|[silent]
# |-heal|p2a: Arbok|235/235 slp|[silent]
# |-heal|p2a: Arbok|235/235 slp|[silent]
# |-status|p2a: Arbok|slp|[from] move: Rest
# |
# |split
# |-heal|p1a: Crobat|48/48|[from] item: Black Sludge
# |-heal|p1a: Crobat|257/257|[from] item: Black Sludge
# |-heal|p1a: Crobat|48/48|[from] item: Black Sludge
# |-heal|p1a: Crobat|257/257|[from] item: Black Sludge
# |-activate|p2a: Arbok|ability: Shed Skin
# |-curestatus|p2a: Arbok|slp|[msg]
# |upkeep
# |turn|43
# |
# |move|p1a: Crobat|Brave Bird|p2a: Arbok
# |split
# |-damage|p2a: Arbok|42/48
# |-damage|p2a: Arbok|42/48
# |-damage|p2a: Arbok|207/235
# |-damage|p2a: Arbok|207/235
# |split
# |-damage|p1a: Crobat|46/48|[from] Recoil
# |-damage|p1a: Crobat|248/257|[from] Recoil
# |-damage|p1a: Crobat|46/48|[from] Recoil
# |-damage|p1a: Crobat|248/257|[from] Recoil
# |move|p2a: Arbok|Rest|p2a: Arbok
# |-status|p2a: Arbok|slp
# |split
# |-heal|p2a: Arbok|48/48 slp|[silent]
# |-heal|p2a: Arbok|48/48 slp|[silent]
# |-heal|p2a: Arbok|235/235 slp|[silent]
# |-heal|p2a: Arbok|235/235 slp|[silent]
# |-status|p2a: Arbok|slp|[from] move: Rest
# |
# |split
# |-heal|p1a: Crobat|48/48|[from] item: Black Sludge
# |-heal|p1a: Crobat|257/257|[from] item: Black Sludge
# |-heal|p1a: Crobat|48/48|[from] item: Black Sludge
# |-heal|p1a: Crobat|257/257|[from] item: Black Sludge
# |upkeep
# |turn|44
# |
# |move|p1a: Crobat|Brave Bird|p2a: Arbok
# |split
# |-damage|p2a: Arbok|42/48 slp
# |-damage|p2a: Arbok|42/48 slp
# |-damage|p2a: Arbok|207/235 slp
# |-damage|p2a: Arbok|207/235 slp
# |split
# |-damage|p1a: Crobat|46/48|[from] Recoil
# |-damage|p1a: Crobat|248/257|[from] Recoil
# |-damage|p1a: Crobat|46/48|[from] Recoil
# |-damage|p1a: Crobat|248/257|[from] Recoil
# |cant|p2a: Arbok|slp
# |
# |split
# |-heal|p1a: Crobat|48/48|[from] item: Black Sludge
# |-heal|p1a: Crobat|257/257|[from] item: Black Sludge
# |-heal|p1a: Crobat|48/48|[from] item: Black Sludge
# |-heal|p1a: Crobat|257/257|[from] item: Black Sludge
# |upkeep
# |turn|45
# |
# |move|p1a: Crobat|Brave Bird|p2a: Arbok
# |split
# |-damage|p2a: Arbok|36/48 slp
# |-damage|p2a: Arbok|36/48 slp
# |-damage|p2a: Arbok|177/235 slp
# |-damage|p2a: Arbok|177/235 slp
# |split
# |-damage|p1a: Crobat|46/48|[from] Recoil
# |-damage|p1a: Crobat|247/257|[from] Recoil
# |-damage|p1a: Crobat|46/48|[from] Recoil
# |-damage|p1a: Crobat|247/257|[from] Recoil
# |cant|p2a: Arbok|slp
# |
# |split
# |-heal|p1a: Crobat|48/48|[from] item: Black Sludge
# |-heal|p1a: Crobat|257/257|[from] item: Black Sludge
# |-heal|p1a: Crobat|48/48|[from] item: Black Sludge
# |-heal|p1a: Crobat|257/257|[from] item: Black Sludge
# |-activate|p2a: Arbok|ability: Shed Skin
# |-curestatus|p2a: Arbok|slp|[msg]
# |upkeep
# |turn|46
# |
# |move|p1a: Crobat|Brave Bird|p2a: Arbok
# |-crit|p2a: Arbok
# |split
# |-damage|p2a: Arbok|0 fnt
# |-damage|p2a: Arbok|0 fnt
# |-damage|p2a: Arbok|0 fnt
# |-damage|p2a: Arbok|0 fnt
# |split
# |-damage|p1a: Crobat|37/48|[from] Recoil
# |-damage|p1a: Crobat|199/257|[from] Recoil
# |-damage|p1a: Crobat|37/48|[from] Recoil
# |-damage|p1a: Crobat|199/257|[from] Recoil
# |faint|p2a: Arbok
# |
# |split
# |-heal|p1a: Crobat|40/48|[from] item: Black Sludge
# |-heal|p1a: Crobat|215/257|[from] item: Black Sludge
# |-heal|p1a: Crobat|40/48|[from] item: Black Sludge
# |-heal|p1a: Crobat|215/257|[from] item: Black Sludge
# |upkeep
# |
# |split
# |switch|p2a: Beartic|Beartic, L83, F|48/48
# |switch|p2a: Beartic|Beartic, L83, F|48/48
# |switch|p2a: Beartic|Beartic, L83, F|293/293
# |switch|p2a: Beartic|Beartic, L83, F|293/293
# |turn|47
# |
# |move|p2a: Beartic|Aqua Jet|p1a: Crobat
# |split
# |-damage|p1a: Crobat|30/48
# |-damage|p1a: Crobat|163/257
# |-damage|p1a: Crobat|30/48
# |-damage|p1a: Crobat|163/257
# |split
# |-damage|p2a: Beartic|43/48|[from] item: Life Orb
# |-damage|p2a: Beartic|43/48|[from] item: Life Orb
# |-damage|p2a: Beartic|264/293|[from] item: Life Orb
# |-damage|p2a: Beartic|264/293|[from] item: Life Orb
# |move|p1a: Crobat|Brave Bird|p2a: Beartic
# |split
# |-damage|p2a: Beartic|24/48g
# |-damage|p2a: Beartic|24/48g
# |-damage|p2a: Beartic|149/293
# |-damage|p2a: Beartic|149/293
# |split
# |-damage|p1a: Crobat|23/48|[from] Recoil
# |-damage|p1a: Crobat|125/257|[from] Recoil
# |-damage|p1a: Crobat|23/48|[from] Recoil
# |-damage|p1a: Crobat|125/257|[from] Recoil
# |
# |split
# |-heal|p1a: Crobat|26/48|[from] item: Black Sludge
# |-heal|p1a: Crobat|141/257|[from] item: Black Sludge
# |-heal|p1a: Crobat|26/48|[from] item: Black Sludge
# |-heal|p1a: Crobat|141/257|[from] item: Black Sludge
# |upkeep
# |turn|48
# |
# |move|p2a: Beartic|Aqua Jet|p1a: Crobat
# |split
# |-damage|p1a: Crobat|15/48
# |-damage|p1a: Crobat|85/257
# |-damage|p1a: Crobat|15/48
# |-damage|p1a: Crobat|85/257
# |split
# |-damage|p2a: Beartic|19/48|[from] item: Life Orb
# |-damage|p2a: Beartic|19/48|[from] item: Life Orb
# |-damage|p2a: Beartic|120/293|[from] item: Life Orb
# |-damage|p2a: Beartic|120/293|[from] item: Life Orb
# |move|p1a: Crobat|Brave Bird|p2a: Beartic
# |split
# |-damage|p2a: Beartic|1/48
# |-damage|p2a: Beartic|1/48
# |-damage|p2a: Beartic|12/293
# |-damage|p2a: Beartic|12/293
# |split
# |-damage|p1a: Crobat|9/48|[from] Recoil
# |-damage|p1a: Crobat|49/257|[from] Recoil
# |-damage|p1a: Crobat|9/48|[from] Recoil
# |-damage|p1a: Crobat|49/257|[from] Recoil
# |
# |split
# |-heal|p1a: Crobat|12/48|[from] item: Black Sludge
# |-heal|p1a: Crobat|65/257|[from] item: Black Sludge
# |-heal|p1a: Crobat|12/48|[from] item: Black Sludge
# |-heal|p1a: Crobat|65/257|[from] item: Black Sludge
# |upkeep
# |turn|49
# |
# |move|p2a: Beartic|Aqua Jet|p1a: Crobat
# |split
# |-damage|p1a: Crobat|2/48
# |-damage|p1a: Crobat|14/257
# |-damage|p1a: Crobat|2/48
# |-damage|p1a: Crobat|14/257
# |split
# |-damage|p2a: Beartic|0 fnt|[from] item: Life Orb
# |-damage|p2a: Beartic|0 fnt|[from] item: Life Orb
# |-damage|p2a: Beartic|0 fnt|[from] item: Life Orb
# |-damage|p2a: Beartic|0 fnt|[from] item: Life Orb
# |faint|p2a: Beartic
# |move|p1a: Crobat|Brave Bird|p2: Beartic|[notarget]
# |-notarget
# |
# |split
# |-heal|p1a: Crobat|5/48|[from] item: Black Sludge
# |-heal|p1a: Crobat|30/257|[from] item: Black Sludge
# |-heal|p1a: Crobat|5/48|[from] item: Black Sludge
# |-heal|p1a: Crobat|30/257|[from] item: Black Sludge
# |upkeep
# |
# |split
# |switch|p2a: Xerneas|Xerneas, L73|48/48
# |switch|p2a: Xerneas|Xerneas, L73|48/48
# |switch|p2a: Xerneas|Xerneas, L73|304/304
# |switch|p2a: Xerneas|Xerneas, L73|304/304
# |-ability|p2a: Xerneas|Fairy Aura
# |turn|50
# |
# |move|p1a: Crobat|Brave Bird|p2a: Xerneas
# |split
# |-damage|p2a: Xerneas|31/48
# |-damage|p2a: Xerneas|31/48
# |-damage|p2a: Xerneas|199/304
# |-damage|p2a: Xerneas|199/304
# |split
# |-damage|p1a: Crobat|0 fnt|[from] Recoil
# |-damage|p1a: Crobat|0 fnt|[from] Recoil
# |-damage|p1a: Crobat|0 fnt|[from] Recoil
# |-damage|p1a: Crobat|0 fnt|[from] Recoil
# |faint|p1a: Crobat
# |move|p2a: Xerneas|Hidden Power|p1: Crobat|[notarget]
# |-notarget
# |
# |upkeep
# |
# |split
# |switch|p1a: Pyukumuku|Pyukumuku, L83, F|48/48
# |switch|p1a: Pyukumuku|Pyukumuku, L83, F|227/227
# |switch|p1a: Pyukumuku|Pyukumuku, L83, F|48/48
# |switch|p1a: Pyukumuku|Pyukumuku, L83, F|227/227
# |turn|51
# |
# |move|p2a: Xerneas|Hidden Power|p1a: Pyukumuku
# |-resisted|p1a: Pyukumuku
# |split
# |-damage|p1a: Pyukumuku|44/48
# |-damage|p1a: Pyukumuku|212/227
# |-damage|p1a: Pyukumuku|44/48
# |-damage|p1a: Pyukumuku|212/227
# |move|p1a: Pyukumuku|Reflect|p1a: Pyukumuku
# |-sidestart|p1: Player 1|Reflect
# |
# |upkeep
# |turn|52
# |
# |move|p2a: Xerneas|Hidden Power|p1a: Pyukumuku
# |-resisted|p1a: Pyukumuku
# |split
# |-damage|p1a: Pyukumuku|41/48
# |-damage|p1a: Pyukumuku|197/227
# |-damage|p1a: Pyukumuku|41/48
# |-damage|p1a: Pyukumuku|197/227
# |move|p1a: Pyukumuku|Reflect||[still]
# |-fail|p1a: Pyukumuku
# |
# |upkeep
# |turn|53
# |
# |move|p2a: Xerneas|Hidden Power|p1a: Pyukumuku
# |-resisted|p1a: Pyukumuku
# |split
# |-damage|p1a: Pyukumuku|38/48
# |-damage|p1a: Pyukumuku|182/227
# |-damage|p1a: Pyukumuku|38/48
# |-damage|p1a: Pyukumuku|182/227
# |move|p1a: Pyukumuku|Reflect||[still]
# |-fail|p1a: Pyukumuku
# |
# |upkeep
# |turn|54
# |
# |move|p2a: Xerneas|Hidden Power|p1a: Pyukumuku
# |-resisted|p1a: Pyukumuku
# |-crit|p1a: Pyukumuku
# |split
# |-damage|p1a: Pyukumuku|33/48
# |-damage|p1a: Pyukumuku|160/227
# |-damage|p1a: Pyukumuku|33/48
# |-damage|p1a: Pyukumuku|160/227
# |move|p1a: Pyukumuku|Reflect||[still]
# |-fail|p1a: Pyukumuku
# |
# |upkeep
# |turn|55
# |
# |move|p2a: Xerneas|Hidden Power|p1a: Pyukumuku
# |-resisted|p1a: Pyukumuku
# |split
# |-damage|p1a: Pyukumuku|30/48
# |-damage|p1a: Pyukumuku|144/227
# |-damage|p1a: Pyukumuku|30/48
# |-damage|p1a: Pyukumuku|144/227
# |move|p1a: Pyukumuku|Reflect||[still]
# |-fail|p1a: Pyukumuku
# |
# |upkeep
# |turn|56
# |
# |move|p2a: Xerneas|Hidden Power|p1a: Pyukumuku
# |-resisted|p1a: Pyukumuku
# |split
# |-damage|p1a: Pyukumuku|27/48
# |-damage|p1a: Pyukumuku|129/227
# |-damage|p1a: Pyukumuku|27/48
# |-damage|p1a: Pyukumuku|129/227
# |move|p1a: Pyukumuku|Reflect||[still]
# |-fail|p1a: Pyukumuku
# |
# |upkeep
# |turn|57
# |
# |move|p2a: Xerneas|Hidden Power|p1a: Pyukumuku
# |-resisted|p1a: Pyukumuku
# |split
# |-damage|p1a: Pyukumuku|23/48
# |-damage|p1a: Pyukumuku|113/227
# |-damage|p1a: Pyukumuku|23/48
# |-damage|p1a: Pyukumuku|113/227
# |move|p1a: Pyukumuku|Reflect||[still]
# |-fail|p1a: Pyukumuku
# |
# |upkeep
# |turn|58
# |
# |move|p2a: Xerneas|Hidden Power|p1a: Pyukumuku
# |-resisted|p1a: Pyukumuku
# |split
# |-damage|p1a: Pyukumuku|20/48
# |-damage|p1a: Pyukumuku|96/227
# |-damage|p1a: Pyukumuku|20/48
# |-damage|p1a: Pyukumuku|96/227
# |move|p1a: Pyukumuku|Reflect||[still]
# |-fail|p1a: Pyukumuku
# |
# |-sideend|p1: Player 1|Reflect
# |upkeep
# |turn|59
# |
# |move|p2a: Xerneas|Hidden Power|p1a: Pyukumuku
# |-resisted|p1a: Pyukumuku
# |split
# |-damage|p1a: Pyukumuku|16/48
# |-damage|p1a: Pyukumuku|80/227
# |-damage|p1a: Pyukumuku|16/48
# |-damage|p1a: Pyukumuku|80/227
# |move|p1a: Pyukumuku|Reflect|p1a: Pyukumuku
# |-sidestart|p1: Player 1|Reflect
# |
# |upkeep
# |turn|60
# |
# |move|p2a: Xerneas|Hidden Power|p1a: Pyukumuku
# |-resisted|p1a: Pyukumuku
# |split
# |-damage|p1a: Pyukumuku|13/48
# |-damage|p1a: Pyukumuku|63/227
# |-damage|p1a: Pyukumuku|13/48
# |-damage|p1a: Pyukumuku|63/227
# |move|p1a: Pyukumuku|Reflect||[still]
# |-fail|p1a: Pyukumuku
# |
# |upkeep
# |turn|61
# |
# |move|p2a: Xerneas|Hidden Power|p1a: Pyukumuku
# |-resisted|p1a: Pyukumuku
# |split
# |-damage|p1a: Pyukumuku|9/48y
# |-damage|p1a: Pyukumuku|46/227
# |-damage|p1a: Pyukumuku|9/48y
# |-damage|p1a: Pyukumuku|46/227
# |move|p1a: Pyukumuku|Reflect||[still]
# |-fail|p1a: Pyukumuku
# |
# |upkeep
# |turn|62
# |
# |move|p2a: Xerneas|Hidden Power|p1a: Pyukumuku
# |-resisted|p1a: Pyukumuku
# |split
# |-damage|p1a: Pyukumuku|6/48
# |-damage|p1a: Pyukumuku|32/227
# |-damage|p1a: Pyukumuku|6/48
# |-damage|p1a: Pyukumuku|32/227
# |move|p1a: Pyukumuku|Reflect||[still]
# |-fail|p1a: Pyukumuku
# |
# |upkeep
# |turn|63
# |
# |move|p2a: Xerneas|Hidden Power|p1a: Pyukumuku
# |-resisted|p1a: Pyukumuku
# |-crit|p1a: Pyukumuku
# |split
# |-damage|p1a: Pyukumuku|2/48
# |-damage|p1a: Pyukumuku|10/227
# |-damage|p1a: Pyukumuku|2/48
# |-damage|p1a: Pyukumuku|10/227
# |move|p1a: Pyukumuku|Reflect||[still]
# |-fail|p1a: Pyukumuku
# |
# |upkeep
# |turn|64
# |
# |move|p2a: Xerneas|Hidden Power|p1a: Pyukumuku
# |-resisted|p1a: Pyukumuku
# |-crit|p1a: Pyukumuku
# |split
# |-damage|p1a: Pyukumuku|0 fnt
# |-damage|p1a: Pyukumuku|0 fnt
# |-damage|p1a: Pyukumuku|0 fnt
# |-damage|p1a: Pyukumuku|0 fnt
# |split
# |-damage|p2a: Xerneas|29/48|[from] ability: Innards Out|[of] p1a: Pyukumuku
# |-damage|p2a: Xerneas|29/48|[from] ability: Innards Out|[of] p1a: Pyukumuku
# |-damage|p2a: Xerneas|189/304|[from] ability: Innards Out|[of] p1a: Pyukumuku
# |-damage|p2a: Xerneas|189/304|[from] ability: Innards Out|[of] p1a: Pyukumuku
# |faint|p1a: Pyukumuku
# |
# |upkeep
# |
# |split
# |switch|p1a: Raichu|Raichu, L83, F|48/48
# |switch|p1a: Raichu|Raichu, L83, F|235/235
# |switch|p1a: Raichu|Raichu, L83, F|48/48
# |switch|p1a: Raichu|Raichu, L83, F|235/235
# |turn|65
# |
# |move|p1a: Raichu|Focus Blast|p2a: Xerneas
# |-resisted|p2a: Xerneas
# |split
# |-damage|p2a: Xerneas|23/48
# |-damage|p2a: Xerneas|23/48
# |-damage|p2a: Xerneas|150/304
# |-damage|p2a: Xerneas|150/304
# |-unboost|p2a: Xerneas|spd|1
# |split
# |-damage|p1a: Raichu|43/48|[from] item: Life Orb
# |-damage|p1a: Raichu|212/235|[from] item: Life Orb
# |-damage|p1a: Raichu|43/48|[from] item: Life Orb
# |-damage|p1a: Raichu|212/235|[from] item: Life Orb
# |move|p2a: Xerneas|Hidden Power|p1a: Raichu
# |split
# |-damage|p1a: Raichu|34/48
# |-damage|p1a: Raichu|169/235
# |-damage|p1a: Raichu|34/48
# |-damage|p1a: Raichu|169/235
# |
# |upkeep
# |turn|66
# |
# |move|p1a: Raichu|Focus Blast|p2a: Xerneas
# |-resisted|p2a: Xerneas
# |split
# |-damage|p2a: Xerneas|15/48
# |-damage|p2a: Xerneas|15/48
# |-damage|p2a: Xerneas|97/304
# |-damage|p2a: Xerneas|97/304
# |split
# |-damage|p1a: Raichu|29/48|[from] item: Life Orb
# |-damage|p1a: Raichu|146/235|[from] item: Life Orb
# |-damage|p1a: Raichu|29/48|[from] item: Life Orb
# |-damage|p1a: Raichu|146/235|[from] item: Life Orb
# |move|p2a: Xerneas|Hidden Power|p1a: Raichu
# |split
# |-damage|p1a: Raichu|20/48
# |-damage|p1a: Raichu|100/235
# |-damage|p1a: Raichu|20/48
# |-damage|p1a: Raichu|100/235
# |
# |-sideend|p1: Player 1|Reflect
# |upkeep
# |turn|67
# |
# |move|p1a: Raichu|Focus Blast|p2a: Xerneas|[miss]
# |-miss|p1a: Raichu|p2a: Xerneas
# |move|p2a: Xerneas|Hidden Power|p1a: Raichu
# |split
# |-damage|p1a: Raichu|10/48
# |-damage|p1a: Raichu|52/235
# |-damage|p1a: Raichu|10/48
# |-damage|p1a: Raichu|52/235
# |
# |upkeep
# |turn|68
# |
# |move|p1a: Raichu|Focus Blast|p2a: Xerneas
# |-resisted|p2a: Xerneas
# |split
# |-damage|p2a: Xerneas|7/48
# |-damage|p2a: Xerneas|7/48
# |-damage|p2a: Xerneas|46/304
# |-damage|p2a: Xerneas|46/304
# |split
# |-damage|p1a: Raichu|5/48|[from] item: Life Orb
# |-damage|p1a: Raichu|29/235|[from] item: Life Orb
# |-damage|p1a: Raichu|5/48|[from] item: Life Orb
# |-damage|p1a: Raichu|29/235|[from] item: Life Orb
# |move|p2a: Xerneas|Hidden Power|p1a: Raichu
# |split
# |-damage|p1a: Raichu|0 fnt
# |-damage|p1a: Raichu|0 fnt
# |-damage|p1a: Raichu|0 fnt
# |-damage|p1a: Raichu|0 fnt
# |faint|p1a: Raichu
# |
# |upkeep
# |
# |split
# |switch|p1a: Bellossom|Bellossom, L83, M|48/48
# |switch|p1a: Bellossom|Bellossom, L83, M|260/260
# |switch|p1a: Bellossom|Bellossom, L83, M|48/48
# |switch|p1a: Bellossom|Bellossom, L83, M|260/260
# |turn|69
# |
# |move|p2a: Xerneas|Hidden Power|p1a: Bellossom
# |-supereffective|p1a: Bellossom
# |split
# |-damage|p1a: Bellossom|33/48
# |-damage|p1a: Bellossom|180/260
# |-damage|p1a: Bellossom|33/48
# |-damage|p1a: Bellossom|180/260
# |move|p1a: Bellossom|Hidden Power|p2a: Xerneas
# |-crit|p2a: Xerneas
# |split
# |-damage|p2a: Xerneas|0 fnt
# |-damage|p2a: Xerneas|0 fnt
# |-damage|p2a: Xerneas|0 fnt
# |-damage|p2a: Xerneas|0 fnt
# |faint|p2a: Xerneas
# |
# |upkeep
# |
# |split
# |switch|p2a: Parasect|Parasect, L83, M|48/48
# |switch|p2a: Parasect|Parasect, L83, M|48/48
# |switch|p2a: Parasect|Parasect, L83, M|235/235
# |switch|p2a: Parasect|Parasect, L83, M|235/235
# |turn|70
# |
# |move|p1a: Bellossom|Hidden Power|p2a: Parasect
# |-supereffective|p2a: Parasect
# |split
# |-damage|p2a: Parasect|30/48
# |-damage|p2a: Parasect|30/48
# |-damage|p2a: Parasect|147/235
# |-damage|p2a: Parasect|147/235
# |move|p2a: Parasect|Knock Off|p1a: Bellossom
# |split
# |-damage|p1a: Bellossom|25/48
# |-damage|p1a: Bellossom|138/260
# |-damage|p1a: Bellossom|25/48
# |-damage|p1a: Bellossom|138/260
# |
# |split
# |-heal|p2a: Parasect|32/48|[from] item: Leftovers
# |-heal|p2a: Parasect|32/48|[from] item: Leftovers
# |-heal|p2a: Parasect|161/235|[from] item: Leftovers
# |-heal|p2a: Parasect|161/235|[from] item: Leftovers
# |upkeep
# |turn|71
# |
# |move|p1a: Bellossom|Hidden Power|p2a: Parasect
# |-supereffective|p2a: Parasect
# |split
# |-damage|p2a: Parasect|14/48
# |-damage|p2a: Parasect|14/48
# |-damage|p2a: Parasect|69/235
# |-damage|p2a: Parasect|69/235
# |move|p2a: Parasect|Knock Off|p1a: Bellossom
# |split
# |-damage|p1a: Bellossom|18/48
# |-damage|p1a: Bellossom|98/260
# |-damage|p1a: Bellossom|18/48
# |-damage|p1a: Bellossom|98/260
# |
# |split
# |-heal|p2a: Parasect|16/48|[from] item: Leftovers
# |-heal|p2a: Parasect|16/48|[from] item: Leftovers
# |-heal|p2a: Parasect|83/235|[from] item: Leftovers
# |-heal|p2a: Parasect|83/235|[from] item: Leftovers
# |upkeep
# |turn|72
# |
# |move|p1a: Bellossom|Hidden Power|p2a: Parasect
# |-supereffective|p2a: Parasect
# |split
# |-damage|p2a: Parasect|0 fnt
# |-damage|p2a: Parasect|0 fnt
# |-damage|p2a: Parasect|0 fnt
# |-damage|p2a: Parasect|0 fnt
# |faint|p2a: Parasect
# |
# |upkeep
# |
# |split
# |switch|p2a: Blissey|Blissey, L77, F|48/48
# |switch|p2a: Blissey|Blissey, L77, F|48/48
# |switch|p2a: Blissey|Blissey, L77, F|519/519
# |switch|p2a: Blissey|Blissey, L77, F|519/519
# |turn|73
# |
# |move|p1a: Bellossom|Hidden Power|p2a: Blissey
# |split
# |-damage|p2a: Blissey|45/48
# |-damage|p2a: Blissey|45/48
# |-damage|p2a: Blissey|487/519
# |-damage|p2a: Blissey|487/519
# |move|p2a: Blissey|Soft-Boiled|p2a: Blissey
# |split
# |-heal|p2a: Blissey|48/48
# |-heal|p2a: Blissey|48/48
# |-heal|p2a: Blissey|519/519
# |-heal|p2a: Blissey|519/519
# |
# |upkeep
# |turn|74
# |
# |move|p1a: Bellossom|Hidden Power|p2a: Blissey
# |split
# |-damage|p2a: Blissey|45/48
# |-damage|p2a: Blissey|45/48
# |-damage|p2a: Blissey|490/519
# |-damage|p2a: Blissey|490/519
# |move|p2a: Blissey|Soft-Boiled|p2a: Blissey
# |split
# |-heal|p2a: Blissey|48/48
# |-heal|p2a: Blissey|48/48
# |-heal|p2a: Blissey|519/519
# |-heal|p2a: Blissey|519/519
# |
# |upkeep
# |turn|75
# |
# |move|p1a: Bellossom|Hidden Power|p2a: Blissey
# |split
# |-damage|p2a: Blissey|45/48
# |-damage|p2a: Blissey|45/48
# |-damage|p2a: Blissey|489/519
# |-damage|p2a: Blissey|489/519
# |move|p2a: Blissey|Soft-Boiled|p2a: Blissey
# |split
# |-heal|p2a: Blissey|48/48
# |-heal|p2a: Blissey|48/48
# |-heal|p2a: Blissey|519/519
# |-heal|p2a: Blissey|519/519
# |
# |upkeep
# |turn|76
# |
# |move|p1a: Bellossom|Hidden Power|p2a: Blissey
# |split
# |-damage|p2a: Blissey|45/48
# |-damage|p2a: Blissey|45/48
# |-damage|p2a: Blissey|490/519
# |-damage|p2a: Blissey|490/519
# |move|p2a: Blissey|Soft-Boiled|p2a: Blissey
# |split
# |-heal|p2a: Blissey|48/48
# |-heal|p2a: Blissey|48/48
# |-heal|p2a: Blissey|519/519
# |-heal|p2a: Blissey|519/519
# |
# |upkeep
# |turn|77
# |
# |move|p1a: Bellossom|Hidden Power|p2a: Blissey
# |split
# |-damage|p2a: Blissey|44/48
# |-damage|p2a: Blissey|44/48
# |-damage|p2a: Blissey|486/519
# |-damage|p2a: Blissey|486/519
# |move|p2a: Blissey|Soft-Boiled|p2a: Blissey
# |split
# |-heal|p2a: Blissey|48/48
# |-heal|p2a: Blissey|48/48
# |-heal|p2a: Blissey|519/519
# |-heal|p2a: Blissey|519/519
# |
# |upkeep
# |turn|78
# |
# |move|p1a: Bellossom|Hidden Power|p2a: Blissey
# |split
# |-damage|p2a: Blissey|45/48
# |-damage|p2a: Blissey|45/48
# |-damage|p2a: Blissey|487/519
# |-damage|p2a: Blissey|487/519
# |move|p2a: Blissey|Soft-Boiled|p2a: Blissey
# |split
# |-heal|p2a: Blissey|48/48
# |-heal|p2a: Blissey|48/48
# |-heal|p2a: Blissey|519/519
# |-heal|p2a: Blissey|519/519
# |
# |upkeep
# |turn|79
# |
# |move|p1a: Bellossom|Hidden Power|p2a: Blissey
# |split
# |-damage|p2a: Blissey|45/48
# |-damage|p2a: Blissey|45/48
# |-damage|p2a: Blissey|490/519
# |-damage|p2a: Blissey|490/519
# |move|p2a: Blissey|Soft-Boiled|p2a: Blissey
# |split
# |-heal|p2a: Blissey|48/48
# |-heal|p2a: Blissey|48/48
# |-heal|p2a: Blissey|519/519
# |-heal|p2a: Blissey|519/519
# |
# |upkeep
# |turn|80
# |
# |move|p1a: Bellossom|Hidden Power|p2a: Blissey
# |split
# |-damage|p2a: Blissey|44/48
# |-damage|p2a: Blissey|44/48
# |-damage|p2a: Blissey|486/519
# |-damage|p2a: Blissey|486/519
# |move|p2a: Blissey|Soft-Boiled|p2a: Blissey
# |split
# |-heal|p2a: Blissey|48/48
# |-heal|p2a: Blissey|48/48
# |-heal|p2a: Blissey|519/519
# |-heal|p2a: Blissey|519/519
# |
# |upkeep
# |turn|81
# |
# |move|p1a: Bellossom|Hidden Power|p2a: Blissey
# |-crit|p2a: Blissey
# |split
# |-damage|p2a: Blissey|43/48
# |-damage|p2a: Blissey|43/48
# |-damage|p2a: Blissey|474/519
# |-damage|p2a: Blissey|474/519
# |move|p2a: Blissey|Soft-Boiled|p2a: Blissey
# |split
# |-heal|p2a: Blissey|48/48
# |-heal|p2a: Blissey|48/48
# |-heal|p2a: Blissey|519/519
# |-heal|p2a: Blissey|519/519
# |
# |upkeep
# |turn|82
# |
# |move|p1a: Bellossom|Hidden Power|p2a: Blissey
# |split
# |-damage|p2a: Blissey|45/48
# |-damage|p2a: Blissey|45/48
# |-damage|p2a: Blissey|490/519
# |-damage|p2a: Blissey|490/519
# |move|p2a: Blissey|Soft-Boiled|p2a: Blissey
# |split
# |-heal|p2a: Blissey|48/48
# |-heal|p2a: Blissey|48/48
# |-heal|p2a: Blissey|519/519
# |-heal|p2a: Blissey|519/519
# |
# |upkeep
# |turn|83
# |
# |move|p1a: Bellossom|Hidden Power|p2a: Blissey
# |split
# |-damage|p2a: Blissey|45/48
# |-damage|p2a: Blissey|45/48
# |-damage|p2a: Blissey|488/519
# |-damage|p2a: Blissey|488/519
# |move|p2a: Blissey|Soft-Boiled|p2a: Blissey
# |split
# |-heal|p2a: Blissey|48/48
# |-heal|p2a: Blissey|48/48
# |-heal|p2a: Blissey|519/519
# |-heal|p2a: Blissey|519/519
# |
# |upkeep
# |turn|84
# |
# |move|p1a: Bellossom|Hidden Power|p2a: Blissey
# |split
# |-damage|p2a: Blissey|45/48
# |-damage|p2a: Blissey|45/48
# |-damage|p2a: Blissey|487/519
# |-damage|p2a: Blissey|487/519
# |move|p2a: Blissey|Soft-Boiled|p2a: Blissey
# |split
# |-heal|p2a: Blissey|48/48
# |-heal|p2a: Blissey|48/48
# |-heal|p2a: Blissey|519/519
# |-heal|p2a: Blissey|519/519
# |
# |upkeep
# |turn|85
# |
# |move|p1a: Bellossom|Hidden Power|p2a: Blissey
# |split
# |-damage|p2a: Blissey|45/48
# |-damage|p2a: Blissey|45/48
# |-damage|p2a: Blissey|491/519
# |-damage|p2a: Blissey|491/519
# |move|p2a: Blissey|Soft-Boiled|p2a: Blissey
# |split
# |-heal|p2a: Blissey|48/48
# |-heal|p2a: Blissey|48/48
# |-heal|p2a: Blissey|519/519
# |-heal|p2a: Blissey|519/519
# |
# |upkeep
# |turn|86
# |
# |move|p1a: Bellossom|Hidden Power|p2a: Blissey
# |split
# |-damage|p2a: Blissey|45/48
# |-damage|p2a: Blissey|45/48
# |-damage|p2a: Blissey|488/519
# |-damage|p2a: Blissey|488/519
# |move|p2a: Blissey|Soft-Boiled|p2a: Blissey
# |split
# |-heal|p2a: Blissey|48/48
# |-heal|p2a: Blissey|48/48
# |-heal|p2a: Blissey|519/519
# |-heal|p2a: Blissey|519/519
# |
# |upkeep
# |turn|87
# |
# |move|p1a: Bellossom|Hidden Power|p2a: Blissey
# |-crit|p2a: Blissey
# |split
# |-damage|p2a: Blissey|44/48
# |-damage|p2a: Blissey|44/48
# |-damage|p2a: Blissey|476/519
# |-damage|p2a: Blissey|476/519
# |move|p2a: Blissey|Soft-Boiled|p2a: Blissey
# |split
# |-heal|p2a: Blissey|48/48
# |-heal|p2a: Blissey|48/48
# |-heal|p2a: Blissey|519/519
# |-heal|p2a: Blissey|519/519
# |
# |upkeep
# |turn|88
# |
# |move|p1a: Bellossom|Hidden Power|p2a: Blissey
# |split
# |-damage|p2a: Blissey|45/48
# |-damage|p2a: Blissey|45/48
# |-damage|p2a: Blissey|488/519
# |-damage|p2a: Blissey|488/519
# |move|p2a: Blissey|Soft-Boiled|p2a: Blissey
# |split
# |-heal|p2a: Blissey|48/48
# |-heal|p2a: Blissey|48/48
# |-heal|p2a: Blissey|519/519
# |-heal|p2a: Blissey|519/519
# |
# |upkeep
# |turn|89
# |
# |move|p1a: Bellossom|Hidden Power|p2a: Blissey
# |split
# |-damage|p2a: Blissey|45/48
# |-damage|p2a: Blissey|45/48
# |-damage|p2a: Blissey|487/519
# |-damage|p2a: Blissey|487/519
# |move|p2a: Blissey|Heal Bell||[still]
# |-activate|p2a: Blissey|move: Heal Bell
# |-fail|p2a: Blissey
# |
# |split
# |-heal|p2a: Blissey|48/48|[from] item: Leftovers
# |-heal|p2a: Blissey|48/48|[from] item: Leftovers
# |-heal|p2a: Blissey|519/519|[from] item: Leftovers
# |-heal|p2a: Blissey|519/519|[from] item: Leftovers
# |upkeep
# |turn|90
# |
# |move|p1a: Bellossom|Hidden Power|p2a: Blissey
# |split
# |-damage|p2a: Blissey|45/48
# |-damage|p2a: Blissey|45/48
# |-damage|p2a: Blissey|489/519
# |-damage|p2a: Blissey|489/519
# |move|p2a: Blissey|Heal Bell||[still]
# |-activate|p2a: Blissey|move: Heal Bell
# |-fail|p2a: Blissey
# |
# |split
# |-heal|p2a: Blissey|48/48|[from] item: Leftovers
# |-heal|p2a: Blissey|48/48|[from] item: Leftovers
# |-heal|p2a: Blissey|519/519|[from] item: Leftovers
# |-heal|p2a: Blissey|519/519|[from] item: Leftovers
# |upkeep
# |turn|91
# |
# |move|p1a: Bellossom|Hidden Power|p2a: Blissey
# |split
# |-damage|p2a: Blissey|45/48
# |-damage|p2a: Blissey|45/48
# |-damage|p2a: Blissey|489/519
# |-damage|p2a: Blissey|489/519
# |move|p2a: Blissey|Heal Bell||[still]
# |-activate|p2a: Blissey|move: Heal Bell
# |-fail|p2a: Blissey
# |
# |split
# |-heal|p2a: Blissey|48/48|[from] item: Leftovers
# |-heal|p2a: Blissey|48/48|[from] item: Leftovers
# |-heal|p2a: Blissey|519/519|[from] item: Leftovers
# |-heal|p2a: Blissey|519/519|[from] item: Leftovers
# |upkeep
# |turn|92
# |
# |move|p1a: Bellossom|Hidden Power|p2a: Blissey
# |split
# |-damage|p2a: Blissey|44/48
# |-damage|p2a: Blissey|44/48
# |-damage|p2a: Blissey|485/519
# |-damage|p2a: Blissey|485/519
# |move|p2a: Blissey|Heal Bell||[still]
# |-activate|p2a: Blissey|move: Heal Bell
# |-fail|p2a: Blissey
# |
# |split
# |-heal|p2a: Blissey|47/48|[from] item: Leftovers
# |-heal|p2a: Blissey|47/48|[from] item: Leftovers
# |-heal|p2a: Blissey|517/519|[from] item: Leftovers
# |-heal|p2a: Blissey|517/519|[from] item: Leftovers
# |upkeep
# |turn|93
# |
# |move|p1a: Bellossom|Giga Drain|p2a: Blissey
# |split
# |-damage|p2a: Blissey|41/48
# |-damage|p2a: Blissey|41/48
# |-damage|p2a: Blissey|454/519
# |-damage|p2a: Blissey|454/519
# |split
# |-heal|p1a: Bellossom|24/48|[from] drain|[of] p2a: Blissey
# |-heal|p1a: Bellossom|130/260|[from] drain|[of] p2a: Blissey
# |-heal|p1a: Bellossom|24/48|[from] drain|[of] p2a: Blissey
# |-heal|p1a: Bellossom|130/260|[from] drain|[of] p2a: Blissey
# |move|p2a: Blissey|Heal Bell||[still]
# |-activate|p2a: Blissey|move: Heal Bell
# |-fail|p2a: Blissey
# |
# |split
# |-heal|p2a: Blissey|44/48|[from] item: Leftovers
# |-heal|p2a: Blissey|44/48|[from] item: Leftovers
# |-heal|p2a: Blissey|486/519|[from] item: Leftovers
# |-heal|p2a: Blissey|486/519|[from] item: Leftovers
# |upkeep
# |turn|94
# |
# |move|p1a: Bellossom|Giga Drain|p2a: Blissey
# |split
# |-damage|p2a: Blissey|39/48
# |-damage|p2a: Blissey|39/48
# |-damage|p2a: Blissey|431/519
# |-damage|p2a: Blissey|431/519
# |split
# |-heal|p1a: Bellossom|29/48|[from] drain|[of] p2a: Blissey
# |-heal|p1a: Bellossom|158/260|[from] drain|[of] p2a: Blissey
# |-heal|p1a: Bellossom|29/48|[from] drain|[of] p2a: Blissey
# |-heal|p1a: Bellossom|158/260|[from] drain|[of] p2a: Blissey
# |move|p2a: Blissey|Heal Bell||[still]
# |-activate|p2a: Blissey|move: Heal Bell
# |-fail|p2a: Blissey
# |
# |split
# |-heal|p2a: Blissey|42/48|[from] item: Leftovers
# |-heal|p2a: Blissey|42/48|[from] item: Leftovers
# |-heal|p2a: Blissey|463/519|[from] item: Leftovers
# |-heal|p2a: Blissey|463/519|[from] item: Leftovers
# |upkeep
# |turn|95
# |
# |move|p1a: Bellossom|Giga Drain|p2a: Blissey
# |split
# |-damage|p2a: Blissey|37/48
# |-damage|p2a: Blissey|37/48
# |-damage|p2a: Blissey|405/519
# |-damage|p2a: Blissey|405/519
# |split
# |-heal|p1a: Bellossom|34/48|[from] drain|[of] p2a: Blissey
# |-heal|p1a: Bellossom|187/260|[from] drain|[of] p2a: Blissey
# |-heal|p1a: Bellossom|34/48|[from] drain|[of] p2a: Blissey
# |-heal|p1a: Bellossom|187/260|[from] drain|[of] p2a: Blissey
# |move|p2a: Blissey|Heal Bell||[still]
# |-activate|p2a: Blissey|move: Heal Bell
# |-fail|p2a: Blissey
# |
# |split
# |-heal|p2a: Blissey|40/48|[from] item: Leftovers
# |-heal|p2a: Blissey|40/48|[from] item: Leftovers
# |-heal|p2a: Blissey|437/519|[from] item: Leftovers
# |-heal|p2a: Blissey|437/519|[from] item: Leftovers
# |upkeep
# |turn|96
# |
# |move|p1a: Bellossom|Giga Drain|p2a: Blissey
# |split
# |-damage|p2a: Blissey|34/48
# |-damage|p2a: Blissey|34/48
# |-damage|p2a: Blissey|377/519
# |-damage|p2a: Blissey|377/519
# |split
# |-heal|p1a: Bellossom|40/48|[from] drain|[of] p2a: Blissey
# |-heal|p1a: Bellossom|217/260|[from] drain|[of] p2a: Blissey
# |-heal|p1a: Bellossom|40/48|[from] drain|[of] p2a: Blissey
# |-heal|p1a: Bellossom|217/260|[from] drain|[of] p2a: Blissey
# |move|p2a: Blissey|Heal Bell||[still]
# |-activate|p2a: Blissey|move: Heal Bell
# |-fail|p2a: Blissey
# |
# |split
# |-heal|p2a: Blissey|37/48|[from] item: Leftovers
# |-heal|p2a: Blissey|37/48|[from] item: Leftovers
# |-heal|p2a: Blissey|409/519|[from] item: Leftovers
# |-heal|p2a: Blissey|409/519|[from] item: Leftovers
# |upkeep
# |turn|97
# |
# |move|p1a: Bellossom|Giga Drain|p2a: Blissey
# |split
# |-damage|p2a: Blissey|32/48
# |-damage|p2a: Blissey|32/48
# |-damage|p2a: Blissey|351/519
# |-damage|p2a: Blissey|351/519
# |split
# |-heal|p1a: Bellossom|45/48|[from] drain|[of] p2a: Blissey
# |-heal|p1a: Bellossom|246/260|[from] drain|[of] p2a: Blissey
# |-heal|p1a: Bellossom|45/48|[from] drain|[of] p2a: Blissey
# |-heal|p1a: Bellossom|246/260|[from] drain|[of] p2a: Blissey
# |move|p2a: Blissey|Stealth Rock|p1a: Bellossom
# |-sidestart|p1: Player 1|move: Stealth Rock
# |
# |split
# |-heal|p2a: Blissey|35/48|[from] item: Leftovers
# |-heal|p2a: Blissey|35/48|[from] item: Leftovers
# |-heal|p2a: Blissey|383/519|[from] item: Leftovers
# |-heal|p2a: Blissey|383/519|[from] item: Leftovers
# |upkeep
# |turn|98
# |
# |move|p1a: Bellossom|Giga Drain|p2a: Blissey
# |split
# |-damage|p2a: Blissey|29/48
# |-damage|p2a: Blissey|29/48
# |-damage|p2a: Blissey|322/519
# |-damage|p2a: Blissey|322/519
# |split
# |-heal|p1a: Bellossom|48/48|[from] drain|[of] p2a: Blissey
# |-heal|p1a: Bellossom|260/260|[from] drain|[of] p2a: Blissey
# |-heal|p1a: Bellossom|48/48|[from] drain|[of] p2a: Blissey
# |-heal|p1a: Bellossom|260/260|[from] drain|[of] p2a: Blissey
# |move|p2a: Blissey|Stealth Rock||[still]
# |-fail|p2a: Blissey
# |
# |split
# |-heal|p2a: Blissey|32/48|[from] item: Leftovers
# |-heal|p2a: Blissey|32/48|[from] item: Leftovers
# |-heal|p2a: Blissey|354/519|[from] item: Leftovers
# |-heal|p2a: Blissey|354/519|[from] item: Leftovers
# |upkeep
# |turn|99
# |
# |move|p1a: Bellossom|Giga Drain|p2a: Blissey
# |split
# |-damage|p2a: Blissey|26/48
# |-damage|p2a: Blissey|26/48
# |-damage|p2a: Blissey|290/519
# |-damage|p2a: Blissey|290/519
# |move|p2a: Blissey|Stealth Rock||[still]
# |-fail|p2a: Blissey
# |
# |split
# |-heal|p2a: Blissey|29/48|[from] item: Leftovers
# |-heal|p2a: Blissey|29/48|[from] item: Leftovers
# |-heal|p2a: Blissey|322/519|[from] item: Leftovers
# |-heal|p2a: Blissey|322/519|[from] item: Leftovers
# |upkeep
# |turn|100
# |
# |move|p1a: Bellossom|Giga Drain|p2a: Blissey
# |split
# |-damage|p2a: Blissey|24/48g
# |-damage|p2a: Blissey|24/48g
# |-damage|p2a: Blissey|261/519
# |-damage|p2a: Blissey|261/519
# |move|p2a: Blissey|Stealth Rock||[still]
# |-fail|p2a: Blissey
# |
# |split
# |-heal|p2a: Blissey|27/48|[from] item: Leftovers
# |-heal|p2a: Blissey|27/48|[from] item: Leftovers
# |-heal|p2a: Blissey|293/519|[from] item: Leftovers
# |-heal|p2a: Blissey|293/519|[from] item: Leftovers
# |upkeep
# |turn|101
# |
# |move|p1a: Bellossom|Giga Drain|p2a: Blissey
# |split
# |-damage|p2a: Blissey|21/48
# |-damage|p2a: Blissey|21/48
# |-damage|p2a: Blissey|233/519
# |-damage|p2a: Blissey|233/519
# |move|p2a: Blissey|Stealth Rock||[still]
# |-fail|p2a: Blissey
# |
# |split
# |-heal|p2a: Blissey|24/48g|[from] item: Leftovers
# |-heal|p2a: Blissey|24/48g|[from] item: Leftovers
# |-heal|p2a: Blissey|265/519|[from] item: Leftovers
# |-heal|p2a: Blissey|265/519|[from] item: Leftovers
# |upkeep
# |turn|102
# |
# |move|p1a: Bellossom|Giga Drain|p2a: Blissey
# |split
# |-damage|p2a: Blissey|18/48
# |-damage|p2a: Blissey|18/48
# |-damage|p2a: Blissey|204/519
# |-damage|p2a: Blissey|204/519
# |move|p2a: Blissey|Stealth Rock||[still]
# |-fail|p2a: Blissey
# |
# |split
# |-heal|p2a: Blissey|21/48|[from] item: Leftovers
# |-heal|p2a: Blissey|21/48|[from] item: Leftovers
# |-heal|p2a: Blissey|236/519|[from] item: Leftovers
# |-heal|p2a: Blissey|236/519|[from] item: Leftovers
# |upkeep
# |turn|103
# |
# |move|p1a: Bellossom|Giga Drain|p2a: Blissey
# |-crit|p2a: Blissey
# |split
# |-damage|p2a: Blissey|13/48
# |-damage|p2a: Blissey|13/48
# |-damage|p2a: Blissey|145/519
# |-damage|p2a: Blissey|145/519
# |move|p2a: Blissey|Stealth Rock||[still]
# |-fail|p2a: Blissey
# |
# |split
# |-heal|p2a: Blissey|16/48|[from] item: Leftovers
# |-heal|p2a: Blissey|16/48|[from] item: Leftovers
# |-heal|p2a: Blissey|177/519|[from] item: Leftovers
# |-heal|p2a: Blissey|177/519|[from] item: Leftovers
# |upkeep
# |turn|104
# |
# |move|p1a: Bellossom|Giga Drain|p2a: Blissey
# |-crit|p2a: Blissey
# |split
# |-damage|p2a: Blissey|8/48
# |-damage|p2a: Blissey|8/48
# |-damage|p2a: Blissey|93/519
# |-damage|p2a: Blissey|93/519
# |move|p2a: Blissey|Stealth Rock||[still]
# |-fail|p2a: Blissey
# |
# |split
# |-heal|p2a: Blissey|11/48|[from] item: Leftovers
# |-heal|p2a: Blissey|11/48|[from] item: Leftovers
# |-heal|p2a: Blissey|125/519|[from] item: Leftovers
# |-heal|p2a: Blissey|125/519|[from] item: Leftovers
# |upkeep
# |turn|105
# |
# |move|p1a: Bellossom|Giga Drain|p2a: Blissey
# |split
# |-damage|p2a: Blissey|6/48
# |-damage|p2a: Blissey|6/48
# |-damage|p2a: Blissey|71/519
# |-damage|p2a: Blissey|71/519
# |move|p2a: Blissey|Stealth Rock||[still]
# |-fail|p2a: Blissey
# |
# |split
# |-heal|p2a: Blissey|9/48|[from] item: Leftovers
# |-heal|p2a: Blissey|9/48|[from] item: Leftovers
# |-heal|p2a: Blissey|103/519|[from] item: Leftovers
# |-heal|p2a: Blissey|103/519|[from] item: Leftovers
# |upkeep
# |turn|106
# |
# |move|p1a: Bellossom|Giga Drain|p2a: Blissey
# |split
# |-damage|p2a: Blissey|4/48
# |-damage|p2a: Blissey|4/48
# |-damage|p2a: Blissey|45/519
# |-damage|p2a: Blissey|45/519
# |move|p2a: Blissey|Stealth Rock||[still]
# |-fail|p2a: Blissey
# |
# |split
# |-heal|p2a: Blissey|7/48|[from] item: Leftovers
# |-heal|p2a: Blissey|7/48|[from] item: Leftovers
# |-heal|p2a: Blissey|77/519|[from] item: Leftovers
# |-heal|p2a: Blissey|77/519|[from] item: Leftovers
# |upkeep
# |turn|107
# |
# |move|p1a: Bellossom|Giga Drain|p2a: Blissey
# |split
# |-damage|p2a: Blissey|1/48
# |-damage|p2a: Blissey|1/48
# |-damage|p2a: Blissey|17/519
# |-damage|p2a: Blissey|17/519
# |move|p2a: Blissey|Stealth Rock||[still]
# |-fail|p2a: Blissey
# |
# |split
# |-heal|p2a: Blissey|4/48|[from] item: Leftovers
# |-heal|p2a: Blissey|4/48|[from] item: Leftovers
# |-heal|p2a: Blissey|49/519|[from] item: Leftovers
# |-heal|p2a: Blissey|49/519|[from] item: Leftovers
# |upkeep
# |turn|108
# |
# |move|p1a: Bellossom|Giga Drain|p2a: Blissey
# |split
# |-damage|p2a: Blissey|0 fnt
# |-damage|p2a: Blissey|0 fnt
# |-damage|p2a: Blissey|0 fnt
# |-damage|p2a: Blissey|0 fnt
# |faint|p2a: Blissey
# |
# |upkeep
# |
# |split
# |switch|p2a: Octillery|Octillery, L83, F|48/48
# |switch|p2a: Octillery|Octillery, L83, F|48/48
# |switch|p2a: Octillery|Octillery, L83, F|260/260
# |switch|p2a: Octillery|Octillery, L83, F|260/260
# |turn|109
# |
# |move|p1a: Bellossom|Sleep Powder|p2a: Octillery
# |-status|p2a: Octillery|slp
# |cant|p2a: Octillery|slp
# |
# |upkeep
# |turn|110
# |
# |move|p1a: Bellossom|Sleep Powder|p2a: Octillery
# |-fail|p2a: Octillery|slp
# |cant|p2a: Octillery|slp
# |
# |upkeep
# |turn|111
# |
# |move|p1a: Bellossom|Sleep Powder|p2a: Octillery
# |-fail|p2a: Octillery|slp
# |cant|p2a: Octillery|slp
# |
# |upkeep
# |turn|112
# |
# |move|p1a: Bellossom|Sleep Powder|p2a: Octillery
# |-fail|p2a: Octillery|slp
# |-curestatus|p2a: Octillery|slp|[msg]
# |move|p2a: Octillery|Hydro Pump|p1a: Bellossom
# |-resisted|p1a: Bellossom
# |split
# |-damage|p1a: Bellossom|37/48
# |-damage|p1a: Bellossom|203/260
# |-damage|p1a: Bellossom|37/48
# |-damage|p1a: Bellossom|203/260
# |
# |upkeep
# |turn|113
# |
# |move|p1a: Bellossom|Sleep Powder|p2a: Octillery|[miss]
# |-miss|p1a: Bellossom|p2a: Octillery
# |move|p2a: Octillery|Hydro Pump|p1a: Bellossom
# |-resisted|p1a: Bellossom
# |split
# |-damage|p1a: Bellossom|26/48
# |-damage|p1a: Bellossom|143/260
# |-damage|p1a: Bellossom|26/48
# |-damage|p1a: Bellossom|143/260
# |
# |upkeep
# |turn|114
# |
# |move|p1a: Bellossom|Sleep Powder|p2a: Octillery
# |-status|p2a: Octillery|slp
# |cant|p2a: Octillery|slp
# |
# |upkeep
# |turn|115
# |
# |move|p1a: Bellossom|Sleep Powder|p2a: Octillery
# |-fail|p2a: Octillery|slp
# |cant|p2a: Octillery|slp
# |
# |upkeep
# |turn|116
# |
# |move|p1a: Bellossom|Sleep Powder|p2a: Octillery
# |-fail|p2a: Octillery|slp
# |cant|p2a: Octillery|slp
# |
# |upkeep
# |turn|117
# |
# |move|p1a: Bellossom|Sleep Powder|p2a: Octillery
# |-fail|p2a: Octillery|slp
# |-curestatus|p2a: Octillery|slp|[msg]
# |move|p2a: Octillery|Hydro Pump|p1a: Bellossom
# |-resisted|p1a: Bellossom
# |split
# |-damage|p1a: Bellossom|15/48
# |-damage|p1a: Bellossom|84/260
# |-damage|p1a: Bellossom|15/48
# |-damage|p1a: Bellossom|84/260
# |
# |upkeep
# |turn|118
# |
# |move|p1a: Bellossom|Sleep Powder|p2a: Octillery
# |-status|p2a: Octillery|slp
# |cant|p2a: Octillery|slp
# |
# |upkeep
# |turn|119
# |
# |move|p1a: Bellossom|Sleep Powder|p2a: Octillery
# |-fail|p2a: Octillery|slp
# |cant|p2a: Octillery|slp
# |
# |upkeep
# |turn|120
# |
# |move|p1a: Bellossom|Sleep Powder|p2a: Octillery|[miss]
# |-miss|p1a: Bellossom|p2a: Octillery
# |-curestatus|p2a: Octillery|slp|[msg]
# |move|p2a: Octillery|Hydro Pump|p1a: Bellossom
# |-resisted|p1a: Bellossom
# |split
# |-damage|p1a: Bellossom|5/48
# |-damage|p1a: Bellossom|30/260
# |-damage|p1a: Bellossom|5/48
# |-damage|p1a: Bellossom|30/260
# |
# |upkeep
# |turn|121
# |
# |move|p1a: Bellossom|Sleep Powder|p2a: Octillery
# |-status|p2a: Octillery|slp
# |cant|p2a: Octillery|slp
# |
# |upkeep
# |turn|122
# |
# |move|p1a: Bellossom|Sleep Powder|p2a: Octillery
# |-fail|p2a: Octillery|slp
# |cant|p2a: Octillery|slp
# |
# |upkeep
# |turn|123
# |
# |move|p1a: Bellossom|Sleep Powder|p2a: Octillery
# |-fail|p2a: Octillery|slp
# |-curestatus|p2a: Octillery|slp|[msg]
# |move|p2a: Octillery|Hydro Pump|p1a: Bellossom|[miss]
# |-miss|p2a: Octillery|p1a: Bellossom
# |
# |upkeep
# |turn|124
# |
# |move|p1a: Bellossom|Sleep Powder|p2a: Octillery
# |-status|p2a: Octillery|slp
# |cant|p2a: Octillery|slp
# |
# |upkeep
# |turn|125
# |
# |move|p1a: Bellossom|Sleep Powder|p2a: Octillery
# |-fail|p2a: Octillery|slp
# |cant|p2a: Octillery|slp
# |
# |upkeep
# |turn|126
# |
# |move|p1a: Bellossom|Sleep Powder|p2a: Octillery
# |-fail|p2a: Octillery|slp
# |-curestatus|p2a: Octillery|slp|[msg]
# |move|p2a: Octillery|Hydro Pump|p1a: Bellossom
# |-resisted|p1a: Bellossom
# |-crit|p1a: Bellossom
# |split
# |-damage|p1a: Bellossom|0 fnt
# |-damage|p1a: Bellossom|0 fnt
# |-damage|p1a: Bellossom|0 fnt
# |-damage|p1a: Bellossom|0 fnt
# |faint|p1a: Bellossom
# |
# |upkeep
# |
# |split
# |switch|p1a: Shuckle|Shuckle, L83, M|48/48
# |switch|p1a: Shuckle|Shuckle, L83, M|169/169
# |switch|p1a: Shuckle|Shuckle, L83, M|48/48
# |switch|p1a: Shuckle|Shuckle, L83, M|169/169
# |split
# |-damage|p1a: Shuckle|36/48|[from] Stealth Rock
# |-damage|p1a: Shuckle|127/169|[from] Stealth Rock
# |-damage|p1a: Shuckle|36/48|[from] Stealth Rock
# |-damage|p1a: Shuckle|127/169|[from] Stealth Rock
# |turn|127
# |
# |move|p2a: Octillery|Hydro Pump|p1a: Shuckle
# |-supereffective|p1a: Shuckle
# |split
# |-damage|p1a: Shuckle|1/48
# |-damage|p1a: Shuckle|2/169
# |-damage|p1a: Shuckle|1/48
# |-damage|p1a: Shuckle|2/169
# |move|p1a: Shuckle|Knock Off|p2a: Octillery
# |split
# |-damage|p2a: Octillery|43/48
# |-damage|p2a: Octillery|43/48
# |-damage|p2a: Octillery|234/260
# |-damage|p2a: Octillery|234/260
# |-enditem|p2a: Octillery|Expert Belt|[from] move: Knock Off|[of] p1a: Shuckle
# |
# |split
# |-heal|p1a: Shuckle|3/48|[from] item: Leftovers
# |-heal|p1a: Shuckle|12/169|[from] item: Leftovers
# |-heal|p1a: Shuckle|3/48|[from] item: Leftovers
# |-heal|p1a: Shuckle|12/169|[from] item: Leftovers
# |upkeep
# |turn|128
# |
# |move|p2a: Octillery|Hydro Pump|p1a: Shuckle
# |-supereffective|p1a: Shuckle
# |split
# |-damage|p1a: Shuckle|0 fnt
# |-damage|p1a: Shuckle|0 fnt
# |-damage|p1a: Shuckle|0 fnt
# |-damage|p1a: Shuckle|0 fnt
# |faint|p1a: Shuckle
# |
# |upkeep
# |
# |split
# |switch|p1a: Infernape|Infernape, L77, M|48/48
# |switch|p1a: Infernape|Infernape, L77, M|244/244
# |switch|p1a: Infernape|Infernape, L77, M|48/48
# |switch|p1a: Infernape|Infernape, L77, M|244/244
# |split
# |-damage|p1a: Infernape|42/48|[from] Stealth Rock
# |-damage|p1a: Infernape|214/244|[from] Stealth Rock
# |-damage|p1a: Infernape|42/48|[from] Stealth Rock
# |-damage|p1a: Infernape|214/244|[from] Stealth Rock
# |turn|129
# |
# |move|p1a: Infernape|Hidden Power|p2a: Octillery
# |-resisted|p2a: Octillery
# |split
# |-damage|p2a: Octillery|39/48
# |-damage|p2a: Octillery|39/48
# |-damage|p2a: Octillery|212/260
# |-damage|p2a: Octillery|212/260
# |move|p2a: Octillery|Fire Blast|p1a: Infernape
# |-resisted|p1a: Infernape
# |split
# |-damage|p1a: Infernape|32/48
# |-damage|p1a: Infernape|165/244
# |-damage|p1a: Infernape|32/48
# |-damage|p1a: Infernape|165/244
# |
# |upkeep
# |turn|130
# |
# |move|p1a: Infernape|Hidden Power|p2a: Octillery
# |-resisted|p2a: Octillery
# |split
# |-damage|p2a: Octillery|35/48
# |-damage|p2a: Octillery|35/48
# |-damage|p2a: Octillery|190/260
# |-damage|p2a: Octillery|190/260
# |move|p2a: Octillery|Fire Blast|p1a: Infernape
# |-resisted|p1a: Infernape
# |split
# |-damage|p1a: Infernape|22/48
# |-damage|p1a: Infernape|116/244
# |-damage|p1a: Infernape|22/48
# |-damage|p1a: Infernape|116/244
# |
# |upkeep
# |turn|131
# |
# |move|p1a: Infernape|Hidden Power|p2a: Octillery
# |-resisted|p2a: Octillery
# |split
# |-damage|p2a: Octillery|31/48
# |-damage|p2a: Octillery|31/48
# |-damage|p2a: Octillery|170/260
# |-damage|p2a: Octillery|170/260
# |move|p2a: Octillery|Fire Blast|p1a: Infernape
# |-resisted|p1a: Infernape
# |split
# |-damage|p1a: Infernape|12/48
# |-damage|p1a: Infernape|66/244
# |-damage|p1a: Infernape|12/48
# |-damage|p1a: Infernape|66/244
# |
# |upkeep
# |turn|132
# |
# |move|p1a: Infernape|Hidden Power|p2a: Octillery
# |-resisted|p2a: Octillery
# |split
# |-damage|p2a: Octillery|27/48
# |-damage|p2a: Octillery|27/48
# |-damage|p2a: Octillery|150/260
# |-damage|p2a: Octillery|150/260
# |move|p2a: Octillery|Fire Blast|p1a: Infernape
# |-resisted|p1a: Infernape
# |split
# |-damage|p1a: Infernape|3/48
# |-damage|p1a: Infernape|16/244
# |-damage|p1a: Infernape|3/48
# |-damage|p1a: Infernape|16/244
# |
# |upkeep
# |turn|133
# |
# |move|p1a: Infernape|Hidden Power|p2a: Octillery
# |-resisted|p2a: Octillery
# |split
# |-damage|p2a: Octillery|23/48
# |-damage|p2a: Octillery|23/48
# |-damage|p2a: Octillery|127/260
# |-damage|p2a: Octillery|127/260
# |move|p2a: Octillery|Fire Blast|p1a: Infernape
# |-resisted|p1a: Infernape
# |split
# |-damage|p1a: Infernape|0 fnt
# |-damage|p1a: Infernape|0 fnt
# |-damage|p1a: Infernape|0 fnt
# |-damage|p1a: Infernape|0 fnt
# |faint|p1a: Infernape
# |
# |win|Player 2
